# %%
# ================== RUN THIS ENTIRE BLOCK TOGETHER ==================

# ---------- LIST METHODS ----------
# (Run this section first if testing separately in Jupyter)
print("list")
students = ["Akshad", "Rian", "Sanika", "John"]
print("Original List:", students)

students.append("Mayank")                      # append() - add item to end
print("After append('Mayank'):", students)

students.insert(1, "Kartik")                    # insert() - insert at specific index
print("After insert(1, 'Kartik'):", students)

students.remove("Sanika")                        # remove() - delete first matching item
print("After remove('Sanika'):", students)

students.sort()                                # sort() - sort the list in place
print("After sort():", students)

removed_student = students.pop(0)              # pop() - remove and return item by index
print("After pop(0):", students)
print("Removed item:", removed_student)


# ---------- TUPLE METHODS ----------
# (Run this section after List section, or independently — no dependency on List)
print("\ntuple")
student_tuple = ("Akshad", "Rian", "Sanika", "John", "Rian")
print("Original Tuple:", student_tuple)

count_akshad = student_tuple.count("Akshad")       # count() - count occurrences of a value
print("count('Akshad'):", count_akshad)

index_sana = student_tuple.index("Sanika")       # index() - find first index of a value
print("index('Sanika'):", index_sana)

sliced = student_tuple[1:3]                    # Slicing - extract a sub-tuple
print("Slicing [1:3]:", sliced)

new_tuple = student_tuple + ("Mayank", "Kartik") # Concatenation - combine two tuples
print("Concatenation (+):", new_tuple)

a, b, c, d, e = student_tuple                  # Unpacking - assign tuple elements to variables
print("Unpacked values:", a, b, c, d, e)


# ---------- DICTIONARY METHODS ----------
# (Run this section after Tuple section, or independently — no dependency on List/Tuple)
print("\ndictionary")
student_dict = {101: "Akshad", 102: "Rian", 103: "Sanika", 104: "John"}
print("Original Dictionary:", student_dict)

print("keys():", list(student_dict.keys()))            # keys() - get all keys
print("values():", list(student_dict.values()))        # values() - get all values
print("items():", list(student_dict.items()))          # items() - get all key-value pairs

roll_no = student_dict.get(105, "Not Found")   # get() - safely fetch value with default
print("get(105, 'Not Found'):", roll_no)

student_dict.update({105: "Mayank", 102: "Pratik"})   # update() - merge/modify entries
print("After update({105: 'Mayank', 102: 'Pratik'}):", student_dict)

removed_val = student_dict.pop(104)            # pop() - remove and return value by key
print("After pop(104):", student_dict, "| Removed value:", removed_val)

student_dict.setdefault(106, "Kartik")          # setdefault() - get or insert default
print("After setdefault(106, 'Kartik'):", student_dict)

# ================== END OF BLOCK ==================
# Out:
# list
# Original List: ['Akshad', 'Rian', 'Sanika', 'John']
# After append('Mayank'): ['Akshad', 'Rian', 'Sanika', 'John', 'Mayank']
# After insert(1, 'Kartik'): ['Akshad', 'Kartik', 'Rian', 'Sanika', 'John', 'Mayank']
# After remove('Sanika'): ['Akshad', 'Kartik', 'Rian', 'John', 'Mayank']
# After sort(): ['Akshad', 'John', 'Kartik', 'Mayank', 'Rian']
# After pop(0): ['John', 'Kartik', 'Mayank', 'Rian']
# Removed item: Akshad
#
# tuple
# Original Tuple: ('Akshad', 'Rian', 'Sanika', 'John', 'Rian')
# count('Akshad'): 1
# index('Sanika'): 2
# Slicing [1:3]: ('Rian', 'Sanika')
# Concatenation (+): ('Akshad', 'Rian', 'Sanika', 'John', 'Rian', 'Mayank', 'Kartik')
# Unpacked values: Akshad Rian Sanika John Rian
#
# dictionary
# Original Dictionary: {101: 'Akshad', 102: 'Rian', 103: 'Sanika', 104: 'John'}
# keys(): [101, 102, 103, 104]
# values(): ['Akshad', 'Rian', 'Sanika', 'John']
# items(): [(101, 'Akshad'), (102, 'Rian'), (103, 'Sanika'), (104, 'John')]
# ...
